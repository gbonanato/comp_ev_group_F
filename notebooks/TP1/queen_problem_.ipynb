# %%
from TP.problems.queens.interface import QueenProblemOrchestrator

orchestrator = QueenProblemOrchestrator(
    board_size=8,
    pop_size=20,
)

# %%
out = orchestrator.run()
out
# Out:
# QueensIndividual(chrm=[1, 5, 7, 2, 0, 3, 6, 4], fitness_calculator=<TP.problems.queens.fitness.QueensBoardFitness object at 0x000001CC97C8D2B0>, _fitness=0)
